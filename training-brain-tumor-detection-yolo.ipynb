# %% [markdown]
# # Training Brain Tumor Detection Yolo

# %% [markdown]
# ## 1. Install library

# %%
# !pip install --upgrade ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.3/949.3 kB 15.7 MB/s eta 0:00:00a 0:00:01
# ...

# %% [markdown]
# ## 2. Import library

# %%
from ultralytics import YOLO
import torch
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## 3. Training

# %% [markdown]
# ### 3.1 Load model YOLO

# %%
model = YOLO("yolov10n.pt")
# Out:
# ...
# 100%|██████████| 5.59M/5.59M [00:00<00:00, 15.9MB/s]

# %% [markdown]
# ## 3.2 Training dataset

# %%
result = model.train(data="/kaggle/input/brain-tumor-detection-yolo/dataset/data.yaml", epochs=100)
# Out:
# Ultralytics 8.3.92 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...
